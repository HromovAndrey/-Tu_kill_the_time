# %% [markdown]
# <a href="https://colab.research.google.com/github/HromovAndrey/-Tu_kill_the_time/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'Name': [
        'Canada',
        'France',
        'Germany',
        'Italy',
        'Japan',
        'United Kingdom',
        'United States',
    ],
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
})

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %%
df.columns
# Out:
# Index(['Name', 'Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.info
# Out:
# <bound method DataFrame.info of              Name  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America>

# %%
df.size
# Out:
# 42

# %%
df.shape
# Out:
# (7, 6)

# %%
df.dtypes
# Out:
# Name             object
# Population      float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %%
df['Population']
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# Name: Population, dtype: float64

# %%
df[['Name', 'Population']]
# Out:
#              Name  Population
# 0          Canada      35.467
# 1          France      63.951
# 2         Germany      80.940
# 3           Italy      60.665
# 4           Japan     127.061
# 5  United Kingdom      64.511
# 6   United States     318.523

# %%
df.iloc[:, 0]
# Out:
# 0            Canada
# 1            France
# 2           Germany
# 3             Italy
# 4             Japan
# 5    United Kingdom
# 6     United States
# Name: Name, dtype: object

# %%
df.loc[:, ['Name', 'Population']]
# Out:
#              Name  Population
# 0          Canada      35.467
# 1          France      63.951
# 2         Germany      80.940
# 3           Italy      60.665
# 4           Japan     127.061
# 5  United Kingdom      64.511
# 6   United States     318.523

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %%
df[df['Population'] > 70]
# Out:
#             Name  Population       GDP  Surface Area    HDI Continent
# 2        Germany      80.940   3874437        357114  0.916    Europe
# 4          Japan     127.061   4602367        377930  0.891      Asia
# 6  United States     318.523  17348075       9525067  0.915   America

# %%
df.loc[df['Population'] > 70, 'Name' ]
# Out:
# 2          Germany
# 4            Japan
# 6    United States
# Name: Name, dtype: object

# %%
df.loc[df['Population'] > 70, ['Name', 'Population', 'GDP']]
# Out:
#             Name  Population       GDP
# 2        Germany      80.940   3874437
# 4          Japan     127.061   4602367
# 6  United States     318.523  17348075

# %%
df.drop(columns=['Population'])
# Out:
#              Name       GDP  Surface Area    HDI Continent
# 0          Canada   1785387       9984670  0.913   America
# 1          France   2833687        640679  0.888    Europe
# 2         Germany   3874437        357114  0.916    Europe
# 3           Italy   2167744        301336  0.873    Europe
# 4           Japan   4602367        377930  0.891      Asia
# 5  United Kingdom   2950039        242495  0.907    Europe
# 6   United States  17348075       9525067  0.915   America

# %%
df.drop(columns=['Population', 'HDI'])
# Out:
#              Name       GDP  Surface Area Continent
# 0          Canada   1785387       9984670   America
# 1          France   2833687        640679    Europe
# 2         Germany   3874437        357114    Europe
# 3           Italy   2167744        301336    Europe
# 4           Japan   4602367        377930      Asia
# 5  United Kingdom   2950039        242495    Europe
# 6   United States  17348075       9525067   America

# %%
df.drop(['Population', 'HDI'], axis=1)
# Out:
#              Name       GDP  Surface Area Continent
# 0          Canada   1785387       9984670   America
# 1          France   2833687        640679    Europe
# 2         Germany   3874437        357114    Europe
# 3           Italy   2167744        301336    Europe
# 4           Japan   4602367        377930      Asia
# 5  United Kingdom   2950039        242495    Europe
# 6   United States  17348075       9525067   America

# %%
df.drop(['Population', 'HDI'], axis='columns')
# Out:
#              Name       GDP  Surface Area Continent
# 0          Canada   1785387       9984670   America
# 1          France   2833687        640679    Europe
# 2         Germany   3874437        357114    Europe
# 3           Italy   2167744        301336    Europe
# 4           Japan   4602367        377930      Asia
# 5  United Kingdom   2950039        242495    Europe
# 6   United States  17348075       9525067   America

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %%
df[['Population', 'GDP']]
# Out:
#    Population       GDP
# 0      35.467   1785387
# 1      63.951   2833687
# 2      80.940   3874437
# 3      60.665   2167744
# 4     127.061   4602367
# 5      64.511   2950039
# 6     318.523  17348075

# %%
df[['Population', 'GDP']]
# Out:
#    Population       GDP
# 0      35.467   1785387
# 1      63.951   2833687
# 2      80.940   3874437
# 3      60.665   2167744
# 4     127.061   4602367
# 5      64.511   2950039
# 6     318.523  17348075

# %%
df['Population'] * 1000
# Out:
# 0     35467.0
# 1     63951.0
# 2     80940.0
# 3     60665.0
# 4    127061.0
# 5     64511.0
# 6    318523.0
# Name: Population, dtype: float64

# %%
df['Poulation'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Poulation'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-c8b26d39e071> in <cell line: 1>()
# ----> 1 df['Poulation'].sum()
#
# ...

# %%
df['GDP'] / df['Population']
# Out:
# 0    50339.385908
# 1    44310.284437
# 2    47868.013343
# 3    35733.025633
# 4    36221.712406
# 5    45729.239975
# 6    54464.120330
# dtype: float64

# %%
df['Population'] = ['English', 'French', 'German', 'Italian', 'Jananese', 'English', 'English']

# %%
df
# Out:
#              Name Population       GDP  Surface Area    HDI Continent
# 0          Canada    English   1785387       9984670  0.913   America
# 1          France     French   2833687        640679  0.888    Europe
# 2         Germany     German   3874437        357114  0.916    Europe
# 3           Italy    Italian   2167744        301336  0.873    Europe
# 4           Japan   Jananese   4602367        377930  0.891      Asia
# 5  United Kingdom    English   2950039        242495  0.907    Europe
# 6   United States    English  17348075       9525067  0.915   America

# %%
df['Languege'] = 'English'

# %%
df
# Out:
#              Name Population       GDP  Surface Area    HDI Continent Languege
# 0          Canada    English   1785387       9984670  0.913   America  English
# 1          France     French   2833687        640679  0.888    Europe  English
# 2         Germany     German   3874437        357114  0.916    Europe  English
# 3           Italy    Italian   2167744        301336  0.873    Europe  English
# 4           Japan   Jananese   4602367        377930  0.891      Asia  English
# 5  United Kingdom    English   2950039        242495  0.907    Europe  English
# 6   United States    English  17348075       9525067  0.915   America  English

# %%
df.rename(
    columns={
        'HDI': 'Human Developmen Index',
        'Anual Popcorn Consumption': 'APC'
    }
)
# Out:
#              Name Population       GDP  Surface Area  Human Developmen Index  \
# 0          Canada    English   1785387       9984670                   0.913
# 1          France     French   2833687        640679                   0.888
# 2         Germany     German   3874437        357114                   0.916
# 3           Italy    Italian   2167744        301336                   0.873
# 4           Japan   Jananese   4602367        377930                   0.891
# 5  United Kingdom    English   2950039        242495                   0.907
# 6   United States    English  17348075       9525067                   0.915
#
#   Continent Languege
# 0   America  English
# 1    Europe  English
# 2    Europe  English
# 3    Europe  English
# 4      Asia  English
# 5    Europe  English
# 6   America  English

# %%
df.drop(columns='Languege', inplace=True)

# %%
df
# Out:
#              Name Population       GDP  Surface Area    HDI Continent
# 0          Canada    English   1785387       9984670  0.913   America
# 1          France     French   2833687        640679  0.888    Europe
# 2         Germany     German   3874437        357114  0.916    Europe
# 3           Italy    Italian   2167744        301336  0.873    Europe
# 4           Japan   Jananese   4602367        377930  0.891      Asia
# 5  United Kingdom    English   2950039        242495  0.907    Europe
# 6   United States    English  17348075       9525067  0.915   America

# %%
df.set_index('Name')
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Name
# Canada            English   1785387       9984670  0.913   America
# France             French   2833687        640679  0.888    Europe
# Germany            German   3874437        357114  0.916    Europe
# Italy             Italian   2167744        301336  0.873    Europe
# Japan            Jananese   4602367        377930  0.891      Asia
# United Kingdom    English   2950039        242495  0.907    Europe
# United States     English  17348075       9525067  0.915   America

# %%
df[['GDP', 'Population']]
# Out:
#         GDP Population
# 0   1785387    English
# 1   2833687     French
# 2   3874437     German
# 3   2167744    Italian
# 4   4602367   Jananese
# 5   2950039    English
# 6  17348075    English

# %%
# Восстановим исходные числовые данные в столбце Population
df['Population'] = [35.467, 63.951, 80.94, 60.665, 127.061, 64.511, 318.523]

# Проверим результат
print(df[['Name', 'Population']])
# Out:
#              Name  Population
# 0          Canada      35.467
# 1          France      63.951
# 2         Germany      80.940
# 3           Italy      60.665
# 4           Japan     127.061
# 5  United Kingdom      64.511
# 6   United States     318.523

# %%
# Преобразование строковых значений в числовые
df['Population'] = pd.to_numeric(df['Population'], errors='coerce')

# Проверим результат
print(df[['Name', 'Population']])
# Out:
#              Name  Population
# 0          Canada      35.467
# 1          France      63.951
# 2         Germany      80.940
# 3           Italy      60.665
# 4           Japan     127.061
# 5  United Kingdom      64.511
# 6   United States     318.523

# %%
df['Population'] = pd.to_numeric(df['Population'], errors='coerce')
print(df[['Name', 'Population']])
# Out:
#              Name  Population
# 0          Canada      35.467
# 1          France      63.951
# 2         Germany      80.940
# 3           Italy      60.665
# 4           Japan     127.061
# 5  United Kingdom      64.511
# 6   United States     318.523

# %%
df = df[pd.to_numeric(df['Population'], errors='coerce').notnull()]
df['Population'] = pd.to_numeric(df['Population'])
print(df[['Name', 'Population']])
# Out:
#              Name  Population
# 0          Canada      35.467
# 1          France      63.951
# 2         Germany      80.940
# 3           Italy      60.665
# 4           Japan     127.061
# 5  United Kingdom      64.511
# 6   United States     318.523

# %%
gdp_per_capita = df['GDP'] / df['Population']
print(gdp_per_capita)
# Out:
# 0    50339.385908
# 1    44310.284437
# 2    47868.013343
# 3    35733.025633
# 4    36221.712406
# 5    45729.239975
# 6    54464.120330
# dtype: float64

# %%
df['GDP Per Capita'] = df['GDP'] / df['Population']

# %%
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent  \
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America
#
#    GDP Per Capita
# 0    50339.385908
# 1    44310.284437
# 2    47868.013343
# 3    35733.025633
# 4    36221.712406
# 5    45729.239975
# 6    54464.120330

# %%
for i, j in zip([0, 2, 2, 5],[5, 3, 6, 3]):
  df.iloc[i, j] = np.nan
df
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent  \
# 0          Canada      35.467   1785387     9984670.0  0.913       NaN
# 1          France      63.951   2833687      640679.0  0.888    Europe
# 2         Germany      80.940   3874437           NaN  0.916    Europe
# 3           Italy      60.665   2167744      301336.0  0.873    Europe
# 4           Japan     127.061   4602367      377930.0  0.891      Asia
# 5  United Kingdom      64.511   2950039           NaN  0.907    Europe
# 6   United States     318.523  17348075     9525067.0  0.915   America
#
#    GDP Per Capita
# 0    50339.385908
# 1    44310.284437
# 2             NaN
# 3    35733.025633
# 4    36221.712406
# 5    45729.239975
# 6    54464.120330

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            7 non-null      object
#  1   Population      7 non-null      float64
#  2   GDP             7 non-null      int64
#  3   Surface Area    5 non-null      float64
#  4   HDI             7 non-null      float64
#  5   Continent       6 non-null      object
#  6   GDP Per Capita  6 non-null      float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 520.0+ bytes

# %%
df['Continent'].isnull()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# Name: Continent, dtype: bool

# %%
df.dropna()
# Out:
#             Name  Population       GDP  Surface Area    HDI Continent  \
# 1         France      63.951   2833687      640679.0  0.888    Europe
# 3          Italy      60.665   2167744      301336.0  0.873    Europe
# 4          Japan     127.061   4602367      377930.0  0.891      Asia
# 6  United States     318.523  17348075     9525067.0  0.915   America
#
#    GDP Per Capita
# 1    44310.284437
# 3    35733.025633
# 4    36221.712406
# 6    54464.120330

# %%
df[~df['Continent'].isnull()]
# Out:
#              Name  Population       GDP  Surface Area    HDI Continent  \
# 1          France      63.951   2833687      640679.0  0.888    Europe
# 2         Germany      80.940   3874437           NaN  0.916    Europe
# 3           Italy      60.665   2167744      301336.0  0.873    Europe
# 4           Japan     127.061   4602367      377930.0  0.891      Asia
# 5  United Kingdom      64.511   2950039           NaN  0.907    Europe
# 6   United States     318.523  17348075     9525067.0  0.915   America
#
#    GDP Per Capita
# 1    44310.284437
# 2             NaN
# 3    35733.025633
# 4    36221.712406
# 5    45729.239975
# 6    54464.120330

# %%
df.to_csv("g7_data.csv")
